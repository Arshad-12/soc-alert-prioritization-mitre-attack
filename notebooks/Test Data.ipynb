# %%
import pandas as pd

df = pd.read_csv('/home/arshad/Network-project/data/final_risk_scored.csv')
df.sample(100, random_state=42).to_csv(
    '/home/arshad/Network-project/data/test_upload.csv',
    index=False
)
print("✅ Test file created!")
print(f"   Rows: 100")
print(f"   Saved to: /home/arshad/Network-project/data/test_upload.csv")
# Out:
# ✅ Test file created!
#    Rows: 100
#    Saved to: /home/arshad/Network-project/data/test_upload.csv
